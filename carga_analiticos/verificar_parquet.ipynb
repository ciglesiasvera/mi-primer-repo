# %%
import pandas as pd

df = pd.read_parquet("data/ventas.parquet")
print(df.head())
# Out:
#    pedido_id  cliente_id producto  precio      fecha
# 0          1           3        B  315.87 2024-01-01
# 1          2           2        C  327.69 2024-01-02
# 2          3           2        A  172.10 2024-01-03
# 3          4           2        C  471.82 2024-01-04
# 4          5           3        A  248.15 2024-01-05
